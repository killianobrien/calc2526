# %%
import sympy
x = sympy.symbols('x')
x
# Out:
# x

# %%
x = sympy.Integer(3)
ests = [x]
ests
# Out:
# [3]

# %%
for n in range(10):
    x = ests[-1]
    y = x - (x**2 -5)/(2*x)
    ests.append(y)

# %%
ests
# Out:
# [3,
#  7/3,
#  47/21,
#  2207/987,
#  4870847/2178309,
#  23725150497407/10610209857723,
#  562882766124611619513723647/251728825683549488150424261,
#  316837008400094222150776738483768236006420971486980607/141693817714056513234709965875411919657707794958199867,
#  100385689891921376688754239992826256704879627683181901515099398613465618884806971304035121947368905594088447/44893845313309942978077298160660626646181883623886239791269694466661322268805744081870933775586567858979269,
#  ...,
#  ...]

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,len(ests)+1),ests,'o')

# %%
for e in ests:
    print(e)
    print('-------------')
# Out:
# 3
# -------------
# 7/3
# -------------
# 47/21
# -------------
# 2207/987
# -------------
# 4870847/2178309
# -------------
# 23725150497407/10610209857723
# -------------
# 562882766124611619513723647/251728825683549488150424261
# -------------
# 316837008400094222150776738483768236006420971486980607/141693817714056513234709965875411919657707794958199867
# -------------
# 100385689891921376688754239992826256704879627683181901515099398613465618884806971304035121947368905594088447/44893845313309942978077298160660626646181883623886239791269694466661322268805744081870933775586567858979269
# -------------
# ...
# -------------
# ...
# -------------

# %%
ests[-1]**2
# Out:
# ...

# %%
y = ests[-1]

# %%
type(y)
# Out:
# sympy.core.numbers.Rational

# %%
y.numerator
# Out:
# ...

# %%
y.denominator
# Out:
# ...

# %%
y**2
# Out:
# ...

# %%
Real(y**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_129154/4214980546.py in <module>
# ----> 1 Real(y**2)
#
# NameError: name 'Real' is not defined

# %%
sympy.RealNumber(y**2)
# Out:
# 5.00000000000000

# %%
for y in ests:
    print(y)
    print(sympy.RealNumber(y**2,1000))
    print('------')
# Out:
# 3
# 9....
# ------
# 7/3
# 5....
# ------
# 47/21
# 5....
# ------
# 2207/987
# 5....
# ------
# 4870847/2178309
# 5....
# ------
# 23725150497407/10610209857723
# 5....
# ------
# 562882766124611619513723647/251728825683549488150424261
# 5....
# ------
# 316837008400094222150776738483768236006420971486980607/141693817714056513234709965875411919657707794958199867
# 5....
# ------
# 100385689891921376688754239992826256704879627683181901515099398613465618884806971304035121947368905594088447/44893845313309942978077298160660626646181883623886239791269694466661322268805744081870933775586567858979269
# 5....
# ------
# ...
# 5....
# ------
# ...
# 5....
# ------

# %%
sympy.RealNumber?
